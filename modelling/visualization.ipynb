# %%
# %matplotlib inline


# %run '/home/promobyte/PycharmProjects/ML-Project1-Branched/modelling/decision_tree_regression.py'
# Out:
# /home/promobyte/PycharmProjects/ML-Project1-Branched/modelling
# ['', 'home', 'promobyte', 'PycharmProjects', 'ML-Project1-Branched']
# /home/promobyte/PycharmProjects/ML-Project1-Branched/processed_cars.csv
# Loaded 11166 rows of data from /home/promobyte/PycharmProjects/ML-Project1-Branched/processed_cars.csv
# 14% of data rows dropped in processing...
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators='warn', n_jobs=8,
#            oob_score=False,
#            random_state=<mtrand.RandomState object at 0x7fc4b77a8ee8>,
#            verbose=0, warm_start=False)
# ...
